# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, GRU, Embedding, Dense, Bidirectional
import matplotlib.pyplot as plt
import nltk
from nltk.translate.bleu_score import sentence_bleu

# %%
data = [
    ("Hello", "नमस्ते"),
    ("How are you?", "आप कैसे हैं?"),
    ("Good morning", "सुप्रभात"),
    ("I love programming", "मुझे प्रोग्रामिंग पसंद है"),
    ("See you soon", "जल्द ही मिलते हैं")
]

# %%
# Convert into DataFrame
df = pd.DataFrame(data, columns=['English', 'Hindi'])

# %%
# Lowercase the text
df['English'] = df['English'].str.lower()
df['Hindi'] = df['Hindi'].str.lower()

# %%
df.head()
# Out:
#               English                      Hindi
# 0               hello                     नमस्ते
# 1        how are you?               आप कैसे हैं?
# 2        good morning                   सुप्रभात
# 3  i love programming  मुझे प्रोग्रामिंग पसंद है
# 4        see you soon          जल्द ही मिलते हैं

# %% [markdown]
# ### Tokenization and Padding

# %%
# Tokenizers for English and Hindi
eng_tokenizer = Tokenizer()
hin_tokenizer = Tokenizer()

# Fit tokenizers
eng_tokenizer.fit_on_texts(df['English'])
hin_tokenizer.fit_on_texts(df['Hindi'])

# %%
# Convert text to sequences
eng_sequences = eng_tokenizer.texts_to_sequences(df['English'])
hin_sequences = hin_tokenizer.texts_to_sequences(df['Hindi'])

# Vocabulary sizes
eng_vocab_size = len(eng_tokenizer.word_index) + 1
hin_vocab_size = len(hin_tokenizer.word_index) + 1

# %%
# Padding sequences
max_len_eng = max(len(seq) for seq in eng_sequences)
max_len_hin = max(len(seq) for seq in hin_sequences)

eng_sequences = pad_sequences(eng_sequences, maxlen=max_len_eng, padding='post')
hin_sequences = pad_sequences(hin_sequences, maxlen=max_len_hin, padding='post')

# %%
print("English Vocabulary Size:", eng_vocab_size)
print("Hindi Vocabulary Size:", hin_vocab_size)
# Out:
# English Vocabulary Size: 12
# Hindi Vocabulary Size: 13

# %% [markdown]
# ## Build Seq2Seq Model (RNN, LSTM, Bi-LSTM)

# %%
def build_model(cell_type='RNN'):
    embedding_dim = 64
    units = 128

    # Encoder
    encoder_inputs = Input(shape=(max_len_eng,))
    enc_emb = Embedding(eng_vocab_size, embedding_dim)(encoder_inputs)

    if cell_type == 'RNN':
        encoder = tf.keras.layers.SimpleRNN(units, return_state=True)
        encoder_outputs, state_h = encoder(enc_emb)
        encoder_states = [state_h]
    elif cell_type == 'LSTM':
        encoder = LSTM(units, return_state=True)
        encoder_outputs, state_h, state_c = encoder(enc_emb)
        encoder_states = [state_h, state_c]
    else:  # Bi-LSTM
        encoder = Bidirectional(LSTM(units, return_state=True, return_sequences=False))
        encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder(enc_emb)
        state_h = tf.keras.layers.Concatenate()([forward_h, backward_h])
        state_c = tf.keras.layers.Concatenate()([forward_c, backward_c])
        encoder_states = [state_h, state_c]

    # Decoder
    decoder_inputs = Input(shape=(max_len_hin,))
    dec_emb_layer = Embedding(hin_vocab_size, embedding_dim)
    dec_emb = dec_emb_layer(decoder_inputs)

    if cell_type == 'RNN':
        decoder = tf.keras.layers.SimpleRNN(units, return_sequences=True, return_state=True)
        decoder_outputs, _ = decoder(dec_emb, initial_state=encoder_states)
    elif cell_type == 'LSTM':
        decoder = LSTM(units, return_sequences=True, return_state=True)
        decoder_outputs, _, _ = decoder(dec_emb, initial_state=encoder_states)
    else:  # Bi-LSTM
        decoder = LSTM(units * 2, return_sequences=True, return_state=True)  # Double units to match encoder's concatenation
        decoder_outputs, _, _ = decoder(dec_emb, initial_state=encoder_states)

    decoder_dense = Dense(hin_vocab_size, activation='softmax')
    decoder_outputs = decoder_dense(decoder_outputs)

    # Model
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    return model

# %% [markdown]
# ### Train the Model

# %%
def train_model(cell_type='RNN'):
    model = build_model(cell_type)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    decoder_input_data = np.roll(hin_sequences, shift=1, axis=1)  # Shift for teacher forcing
    decoder_input_data[:, 0] = 0  # First token is always 0 (start token)

    model.fit([eng_sequences, decoder_input_data], hin_sequences, batch_size=16, epochs=50, verbose=1)
    return model

# Train RNN, LSTM, and Bi-LSTM models
rnn_model = train_model('RNN')
lstm_model = train_model('LSTM')
bilstm_model = train_model('Bi-LSTM')
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0000e+00 - loss: 2.5787
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2500 - loss: 2.4926
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 2.4063
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8500 - loss: 2.3162
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8500 - loss: 2.2194
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9000 - loss: 2.1131
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9500 - loss: 1.9953
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9000 - loss: 1.8647
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9000 - loss: 1.7223
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9000 - loss: 1.5721
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9000 - loss: 1.4217
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8500 - loss: 1.2799
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7500 - loss: 1.1525
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7500 - loss: 1.0398
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8000 - loss: 0.9368
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8500 - loss: 0.8383
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9500 - loss: 0.7422
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9500 - loss: 0.6501
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.5644
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.4869
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.4179
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.3574
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.3044
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.2582
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.2179
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1831
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1532
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1278
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.1066
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0890
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0745
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0627
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0531
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0453
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0391
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0340
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0263
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0234
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0208
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0186
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0149
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0000e+00 - loss: 2.5668
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4000 - loss: 2.5554
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.3500 - loss: 2.5439
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 2.5317
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3500 - loss: 2.5184
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 2.5037
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 2.4871
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3500 - loss: 2.4680
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3500 - loss: 2.4461
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3500 - loss: 2.4205
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3500 - loss: 2.3905
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.3500 - loss: 2.3553
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 2.3138
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 2.2652
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3500 - loss: 2.2086
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3500 - loss: 2.1439
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 2.0725
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3500 - loss: 1.9984
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3500 - loss: 1.9290
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3500 - loss: 1.8738
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 1.8404
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3500 - loss: 1.8282
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3500 - loss: 1.8262
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3500 - loss: 1.8208
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3500 - loss: 1.8054
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3500 - loss: 1.7807
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 1.7515
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 1.7227
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 1.6976
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 1.6776
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.3500 - loss: 1.6623
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6000 - loss: 1.6506
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5500 - loss: 1.6408
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5000 - loss: 1.6310
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 1.6201
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 1.6069
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5000 - loss: 1.5913
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - loss: 1.5730
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - loss: 1.5526
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4500 - loss: 1.5303
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4500 - loss: 1.5071
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4500 - loss: 1.4836
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4500 - loss: 1.4609
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4500 - loss: 1.4396
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4500 - loss: 1.4201
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.4500 - loss: 1.4017
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4500 - loss: 1.3829
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4500 - loss: 1.3620
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.4500 - loss: 1.3383
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.4500 - loss: 1.3122
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.0000e+00 - loss: 2.5678
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3500 - loss: 2.5519
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3500 - loss: 2.5355
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3500 - loss: 2.5178
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3500 - loss: 2.4976
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3500 - loss: 2.4738
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.3500 - loss: 2.4452
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3500 - loss: 2.4103
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3500 - loss: 2.3673
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3500 - loss: 2.3141
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3500 - loss: 2.2486
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3500 - loss: 2.1692
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3500 - loss: 2.0772
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3500 - loss: 1.9802
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.3500 - loss: 1.8950
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3500 - loss: 1.8407
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3500 - loss: 1.8232
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3500 - loss: 1.8216
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.3500 - loss: 1.8063
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.3500 - loss: 1.7698
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3500 - loss: 1.7223
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3500 - loss: 1.6769
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.3500 - loss: 1.6410
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3500 - loss: 1.6158
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4000 - loss: 1.5983
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5000 - loss: 1.5841
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5500 - loss: 1.5692
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5500 - loss: 1.5508
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.5000 - loss: 1.5273
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4500 - loss: 1.4985
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.4500 - loss: 1.4646
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4500 - loss: 1.4266
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4500 - loss: 1.3862
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4500 - loss: 1.3458
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4500 - loss: 1.3081
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4500 - loss: 1.2737
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4500 - loss: 1.2403
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4500 - loss: 1.2043
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5500 - loss: 1.1643
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5500 - loss: 1.1214
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5500 - loss: 1.0793
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5500 - loss: 1.0411
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5500 - loss: 1.0077
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6000 - loss: 0.9768
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6500 - loss: 0.9457
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6000 - loss: 0.9140
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6500 - loss: 0.8823
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6500 - loss: 0.8513
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6500 - loss: 0.8219
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6000 - loss: 0.7939

# %%
def evaluate_translation(model, input_text):
    sequence = eng_tokenizer.texts_to_sequences([input_text.lower()])
    sequence = pad_sequences(sequence, maxlen=max_len_eng, padding='post')

    prediction = model.predict([sequence, np.zeros((1, max_len_hin))])  # Empty decoder input
    predicted_sequence = np.argmax(prediction, axis=-1)[0]

    output_words = [word for i in predicted_sequence if (word := hin_tokenizer.index_word.get(i))]
    return ' '.join(output_words)

# Example translations
test_sentences = ["Hello", "How are you?", "Good morning"]

for sentence in test_sentences:
    print(f"\n**Input:** {sentence}")
    print(f"**RNN Output:** {evaluate_translation(rnn_model, sentence)}")
    print(f"**LSTM Output:** {evaluate_translation(lstm_model, sentence)}")
    print(f"**Bi-LSTM Output:** {evaluate_translation(bilstm_model, sentence)}")
# Out:
# **Input:** Hello
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# **RNN Output:** नमस्ते
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# **LSTM Output:**
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# **Bi-LSTM Output:** नमस्ते
#
# **Input:** How are you?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# **RNN Output:** आप कैसे हैं
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# **LSTM Output:**
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# **Bi-LSTM Output:** आप हैं
#
# **Input:** Good morning
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# **RNN Output:** सुप्रभात
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# **LSTM Output:**
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# **Bi-LSTM Output:** नमस्ते

# %% [markdown]
# ### Compute BLEU Score

# %%
def compute_bleu(model, test_pairs):
    bleu_scores = []
    for eng, hin in test_pairs:
        predicted = evaluate_translation(model, eng)
        reference = [hin.split()]  # Reference translation as a list of words
        candidate = predicted.split()
        bleu_scores.append(sentence_bleu(reference, candidate))
    return np.mean(bleu_scores)

print("\nBLEU Scores:")
print(f"RNN Model: {compute_bleu(rnn_model, data)}")
print(f"LSTM Model: {compute_bleu(lstm_model, data)}")
print(f"Bi-LSTM Model: {compute_bleu(bilstm_model, data)}")
# Out:
# BLEU Scores:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# RNN Model: 0.4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# LSTM Model: 3.703621506333808e-232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Bi-LSTM Model: 1.7272337110188993e-78

# %% [markdown]
# ### Compare Teacher Forcing vs. No Teacher Forcing

# %%
def train_without_teacher_forcing(cell_type='RNN'):
    model = build_model(cell_type)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    model.fit([eng_sequences, hin_sequences], hin_sequences, batch_size=16, epochs=50, verbose=1)  # No teacher forcing
    return model

rnn_no_tf_model = train_without_teacher_forcing('RNN')
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1500 - loss: 2.5682
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4000 - loss: 2.4726
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8500 - loss: 2.3764
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9000 - loss: 2.2759
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9000 - loss: 2.1679
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9000 - loss: 2.0497
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9500 - loss: 1.9198
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9500 - loss: 1.7788
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.6301
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 1.4803
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.3369
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 1.2042
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.0817
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.9675
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.8607
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.7616
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.6713
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.5900
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.5171
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.4517
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.3927
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.3395
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.2916
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2488
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.2108
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.1776
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1491
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.1249
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.1047
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0881
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0745
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0635
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0546
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0474
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0414
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0364
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0323
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0287
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0256
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0229
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0205
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 1.0000 - loss: 0.0167
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0151
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0089

# %% [markdown]
# ## Questions and Answers

# %% [markdown]
# 1.   **Difference between RNN, LSTM, and Bi-LSTM in Machine Translation**
#
#     *   RNN: Processes sequences sequentially but suffers from vanishing gradient issues.
#     *   LSTM: Uses gates (input, forget, output) to retain long-term dependencies.
#     *   Bi-LSTM: Processes sequences in both forward and backward directions, improving context understanding.
#
#
# 2.   **Why is LSTM preferred over vanilla RNNs for Seq2Seq tasks?**
#
#     *   LSTM solves the vanishing gradient problem, allowing better retention of long-term dependencies.
#     *   Helps in handling long sequences where RNNs struggle.
#
#
# 3.   **How does the bidirectional nature of Bi-LSTM improve translation accuracy?**
#
#     *   Captures both past and future context, making translations more accurate.
#     *   Provides better context awareness, especially for longer sentences.
#
# 4.   **What is teacher forcing, and how does it impact training?**
#
#     *   Teacher Forcing: During training, instead of using the predicted word as the next input, the actual target word is fed.
#     *   Impact:
#
#         *   Faster convergence.
#         *   Reduces error accumulation.
#
# 5. **How is BLEU Score calculated and its significance?**
#
#     * BLEU Score (Bilingual Evaluation Understudy):
#
#         *   Compares machine-translated output with reference translations.
#         *   Uses n-gram precision and applies brevity penalty for short translations.
#
#     * Significance:
#
#         *   Measures how closely a model’s output matches human translations.
#         *   Higher BLEU = Better translation quality.
